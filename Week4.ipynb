# %% [markdown]
# <a href="https://colab.research.google.com/github/imYours14/PCVK_Genap_2023/blob/main/Week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Tugas Praktikum

# %%
print('=============================') 
print(' Gamma Correction pada citra ') 
print('=============================') 
try: 
 gamma = int(input('Masukkan nilai Gamma: ')) 
except ValueError: 
 print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/PCVK/Week4/female.tiff')
gamma_image = np.zeros(original.shape, original.dtype)
#----------------------------------------------#
for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      gamma_image[y,x,c] = np.clip(255 * pow(original[y,x,c]/255, (1/gamma)), 0, 255)

final_frame = cv.hconcat((original, gamma_image))
cv2_imshow(final_frame)
# Out:
# =============================
#  Gamma Correction pada citra
# =============================
# Masukkan nilai Gamma: 3
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FB2E015BEB0>

# %%
print('======================') 
print(' Bit Depth pada Citra ')
print('======================') 
try:
  bit_depth = int(input('Masukkan nilai Bit Depth: '))
except ValueError:
  print('Error, not a number')

bit = 2**bit_depth
level = 255/(bit-1)

bit_depth_image = np.zeros(original.shape, original.dtype)

for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      bit_depth_image[y,x,c] = np.clip(round(original[y,x,c] / level) * level, 0, 255)

final_frame = cv.hconcat((original, bit_depth_image))
cv2_imshow(final_frame)
# Out:
# ======================
#  Bit Depth pada Citra
# ======================
# Masukkan nilai Bit Depth: 2
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FB2E0560A30>

# %%
import glob
from math import log10, sqrt

print('===========================') 
print(' Average Denoising 5 citra ')
print('===========================') 

img_amt = 5

def PSNR(ori, compressed):
  mse = np.mean((ori - compressed) ** 2)
  if(mse == 0):
    return 100
  max_pixel = 255.0
  psnr = 20 * log10(max_pixel / sqrt(mse))
  return psnr

ori = cv.imread('/content/drive/MyDrive/PCVK/Week4/galaxy.jpg')
denoising_avg = np.zeros(ori.shape, ori.dtype)

cv_img = []
for i in glob.glob('/content/drive/MyDrive/PCVK/Week4/noises/*.jpg'):
  n = cv.imread(i)
  cv_img.append(n)

denoising_avg = np.mean(cv_img[:img_amt], axis=0).astype(np.uint8)

value = PSNR(ori, denoising_avg)
print(f"Nilai PSNR: {value} dB")

final_frame = cv.hconcat((ori, denoising_avg))
cv2_imshow(denoising_avg)
# Out:
# ===========================
#  Average Denoising 5 citra
# ===========================
# Nilai PSNR: 27.541363880547827 dB
# <PIL.Image.Image image mode=RGB size=310x256 at 0x7FB2DDDE7400>

# %%
import glob
from math import log10, sqrt

print('===========================') 
print(' Average Denoising 50 citra ')
print('===========================') 

img_amt = 50

def PSNR(ori, compressed):
  mse = np.mean((ori - compressed) ** 2)
  if(mse == 0):
    return 100
  max_pixel = 255.0
  psnr = 20 * log10(max_pixel / sqrt(mse))
  return psnr

ori = cv.imread('/content/drive/MyDrive/PCVK/Week4/galaxy.jpg')
denoising_avg = np.zeros(ori.shape, ori.dtype)

cv_img = []
for i in glob.glob('/content/drive/MyDrive/PCVK/Week4/noises/*.jpg'):
  n = cv.imread(i)
  cv_img.append(n)

denoising_avg = np.mean(cv_img[:img_amt], axis=0).astype(np.uint8)

value = PSNR(ori, denoising_avg)
print(f"Nilai PSNR: {value} dB")

final_frame = cv.hconcat((ori, denoising_avg))
cv2_imshow(denoising_avg)
# Out:
# ===========================
#  Average Denoising 50 citra
# ===========================
# Nilai PSNR: 27.43689937914209 dB
# <PIL.Image.Image image mode=RGB size=310x256 at 0x7FB2DDDFCFD0>

# %%
import glob
from math import log10, sqrt

print('===========================') 
print(' Average Denoising 80 citra ')
print('===========================') 

img_amt = 80

def PSNR(ori, compressed):
  mse = np.mean((ori - compressed) ** 2)
  if(mse == 0):
    return 100
  max_pixel = 255.0
  psnr = 20 * log10(max_pixel / sqrt(mse))
  return psnr

ori = cv.imread('/content/drive/MyDrive/PCVK/Week4/galaxy.jpg')
denoising_avg = np.zeros(ori.shape, ori.dtype)

cv_img = []
for i in glob.glob('/content/drive/MyDrive/PCVK/Week4/noises/*.jpg'):
  n = cv.imread(i)
  cv_img.append(n)

denoising_avg = np.mean(cv_img[:img_amt], axis=0).astype(np.uint8)

value = PSNR(ori, denoising_avg)
print(f"Nilai PSNR: {value} dB")

final_frame = cv.hconcat((ori, denoising_avg))
cv2_imshow(denoising_avg)
# Out:
# ===========================
#  Average Denoising 80 citra
# ===========================
# Nilai PSNR: 27.408386959645412 dB
# <PIL.Image.Image image mode=RGB size=310x256 at 0x7FB2DDE009D0>

# %%
import glob
from math import log10, sqrt

print('===========================') 
print(' Average Denoising 100 citra ')
print('===========================') 

img_amt = 100

def PSNR(ori, compressed):
  mse = np.mean((ori - compressed) ** 2)
  if(mse == 0):
    return 100
  max_pixel = 255.0
  psnr = 20 * log10(max_pixel / sqrt(mse))
  return psnr

ori = cv.imread('/content/drive/MyDrive/PCVK/Week4/galaxy.jpg')
denoising_avg = np.zeros(ori.shape, ori.dtype)

cv_img = []
for i in glob.glob('/content/drive/MyDrive/PCVK/Week4/noises/*.jpg'):
  n = cv.imread(i)
  cv_img.append(n)

denoising_avg = np.mean(cv_img[:img_amt], axis=0).astype(np.uint8)

value = PSNR(ori, denoising_avg)
print(f"Nilai PSNR: {value} dB")

final_frame = cv.hconcat((ori, denoising_avg))
cv2_imshow(denoising_avg)
# Out:
# ===========================
#  Average Denoising 100 citra
# ===========================
# Nilai PSNR: 27.370931279516654 dB
# <PIL.Image.Image image mode=RGB size=310x256 at 0x7FB318034EE0>

# %%
original = cv.imread('/content/drive/MyDrive/PCVK/Week4/couple.tiff')
couple_mask = np.zeros(original.shape, dtype = np.uint8)
blank_img = np.zeros(ori.shape, ori.dtype)

couple_mask = cv.circle(black_img,center=(256,256),radius=50,color=(255,255,255),thickness=-1)
result = original & couple_mask

couple_mask1 = cv.rectangle(couple_mask, pt1 = (405, 5), pt2 = (850, 455), color=(255,255,255), thickness =-1)
result = original & couple_mask1

final_frame = cv.hconcat((original, result))
cv2_imshow(final_frame)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-9be0d77af4a2> in <module>
#       3 blank_img = np.zeros(ori.shape, ori.dtype)
#       4
# ----> 5 couple_mask = cv.circle(black_img,center=(256,256),radius=50,color=(255,0,0),thickness=-1)
#       6 result = original & couple_mask
#       7
#
# NameError: name 'black_img' is not defined
