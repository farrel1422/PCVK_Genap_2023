# %% [markdown]
# <a href="https://colab.research.google.com/github/imYours14/PCVK_Genap_2023/blob/main/Week_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktikum

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('/content/drive/MyDrive/PCVK/Week2/kitten01.jpg')

plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/Week2/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(400,400),radius=50,color=(255,0,0),thickness=-1)
for x in range (500):
  black_img[x,int(x*(500/500))] = [255,255,255]
# cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Farrel',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Farrel',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100, 300], [200, 200], [400, 300], [200, 400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1, 1, 2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2, [pts], isClosed=True, color=(255, 0, 0), thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# Tugas

# %% [markdown]
# 1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga
# berubah?
# 2. Tampilkan image dalam channel Red-Blue dan Green-Blue saja!
# 3. Tampilkan image baris ke 20-115, kolom 25-120!
# 4. Tampilkan image baris ke 5-30, semua kolom, channel Red saja!
# 5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.
# disarankan menggunakan bilangan acak/random!
# 6. Tampilkan image dengan posisi terbalik!

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/Week2/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap='RdGy')

# %%
plt.imshow(img_gray, cmap='GnBu')

# %%
plt.imshow(img3[20:115, 25:120])

# %%
plt.imshow(img_gray[5:30], cmap="Reds")

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)

cv.rectangle(img5,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=10)
cv.rectangle(img5,pt1=(400,400),pt2=(700,700),color=(0,255,0),thickness=10)
cv.rectangle(img5,pt1=(1000,1000),pt2=(800,800),color=(255,0,0),thickness=10)
cv.rectangle(img5,pt1=(1200,1200),pt2=(1050,1050),color=(255,255,255),thickness=10)
cv.rectangle(img5,pt1=(2200,2200),pt2=(1500,1500),color=(0,0,0),thickness=10)


plt.imshow(img5)

# %%
foto = cv.imread("/content/drive/MyDrive/PCVK/Week2/foto.jpg")

foto = cv.cvtColor(foto, cv.COLOR_BGR2RGB)

cv.rectangle(foto, pt1=(150, 125), pt2=(110, 170), color=(255, 0, 0), thickness=1)
cv.circle(foto, center=(130, 140), radius=25, color=(0, 255, 0), thickness=1)

plt.imshow(foto)

# %%
peppers = cv.imread("/content/drive/MyDrive/PCVK/Week2/peppers.jpg")

peppers_rgb = cv.cvtColor(peppers, cv.COLOR_BGR2RGB)

cv.rectangle(peppers_rgb, pt1=(0, 400), pt2=(200, 600), color=(0, 0, 0), thickness=5)

plt.imshow(peppers_rgb)


font = cv.FONT_ITALIC
cv.putText(peppers_rgb, text="Peppers.jpg", org=(200, 350), fontFace=font, fontScale=2, color=(0, 0, 0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(peppers_rgb)

# %%
anime= cv.imread('/content/drive/MyDrive/PCVK/Week2/anime.jpg')
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img4 = img[:,:,1]
img5 = img[:,:,2]
img6 = img[:,:,0]
plt.imshow(img6)
